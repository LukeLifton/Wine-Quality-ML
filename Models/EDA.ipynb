# %% [markdown]
# # EDA (Exploratory Data analysis)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('WineQuality.csv')

# %%
# Display the head of the DataFrame
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.hist(bins = 20 , figsize = (10, 10))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %% [markdown]
# ## Removing NAN data

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
for col in df.columns:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].mean(), inplace=True)

df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Removing irrelevant data

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        try:
            df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric, replace non-convertibles with NaN
        except:
            pass  # Skip columns that cannot be converted

plt.figure(figsize=(12, 12))
sns.heatmap(abs(df.corr()), annot=True, cbar=False)
plt.show()

# %% [markdown]
# Here we can observe which items are closely correlated. Two stand-outs are noticed, total sulphur dioxide and free sulphur dioxide, and density with alcohol. It is logical that both these sets of quantities are linked but to remove unnecessary processing time we can remove one of the sulphur dioxide categories as they are obviously linked.

# %%
df.drop(columns=['total sulfur dioxide'])
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      NaN            7.0             0.270         0.36            20.7
# 1      NaN            6.3             0.300         0.34             1.6
# 2      NaN            8.1             0.280         0.40             6.9
# 3      NaN            7.2             0.230         0.32             8.5
# 4      NaN            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492   NaN            6.2             0.600         0.08             2.0
# 6493   NaN            5.9             0.550         0.10             2.2
# 6494   NaN            6.3             0.510         0.13             2.3
# 6495   NaN            5.9             0.645         0.12             2.0
# 6496   NaN            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  density    pH  sulphates  alcohol  \
# ...
